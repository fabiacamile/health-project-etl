# %% [markdown]
# <a href="https://colab.research.google.com/github/fabiacamile/projects_ETL/blob/main/Orienta%C3%A7%C3%A3o_M%C3%A9dica_com_IA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Projeto ETL com Python

# %% [markdown]
# **Contexto:** Projeto realizado durante o bootcamp Santander - Ciência de Dados, visando exercitar o pipeline de ETL, utlizando da API openai, para gerar mensagens personalizadas
#
# **Utilização:** Gerar mensagens personalizadas a pacientes, de acordo com suas singularidades, melhorando sua experiencia, resultado e assertividade do monitoramento e orientação.

# %% [markdown]
# ## **E**xtract
#
# Extração dos dados, hábitos e condições de pacientes, a partir do arquivo CSV.

# %%
import pandas as pd

df = pd.read_csv('DB_pacientes.csv')
pacientes = df
display(pacientes.head())
# Out:
#    id    nome  idade       sexo  altura  peso  pressao_sistolica  \
# 0   1    João     45  Masculino     175    80                120
# 1   2   Maria     32   Feminino     160    55                110
# 2   3  Carlos     50  Masculino     180    85                130
# 3   4     Ana     28   Feminino     165    50                110
# 4   5   Paulo     62  Masculino     170    75                125
#
#    pressao_diastolica doencas_preexistentes pratica_exercicio fumo  \
# 0                  80       Diabetes tipo 1      Semanalmente  Não
# 1                  70               Nenhuma    Ocasionalmente  Não
# 2                  85       Diabetes tipo 2      Semanalmente  Não
# 3                  75               Nenhuma             Nunca  Não
# 4                  80           Hipertensão             Nunca  Sim
#
#   checkup_ultimo_ano  filhos
# 0                SIM       2
# 1                NÃO       0
# 2                SIM       3
# 3                NÃO       1
# ...

# %% [markdown]
# ## **T**ransform
#
# Utilização da API do OpenAI GPT-4 para gerar uma mensagem personalizada para cada paciente, de acordo com suas condições e hábitos.

# %%
# !pip install openai

# %%
# Documentação Oficial da API OpenAI: https://platform.openai.com/docs/api-reference/introduction
# Informações sobre o Período Gratuito: https://help.openai.com/en/articles/4936830

# Para gerar uma API Key:
# 1. Crie uma conta na OpenAI
# 2. Acesse a seção "API Keys"
# 3. Clique em "Create API Key"
# Link direto: https://platform.openai.com/account/api-keys

# Substitua o texto TODO por sua API Key da OpenAI, ela será salva como uma variável de ambiente.
openai_api_key = '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'

# %%
import openai

openai.api_key = openai_api_key

# Função para gerar a mensagem personalizada
def mensagem_ai(paciente):
  completion = openai.ChatCompletion.create(
    model="gpt-4",
    messages=[
      {
          "role": "system",
          "content": "Você é um especialista em saúde e está monitorando seus pacientes."
      },
      {
          "role": "user",
          "content": f"Crie uma mensagem para {paciente['nome']} com orientações de saúde de acordo com seus hábitos: {paciente['doencas_preexistentes']} {paciente['pratica_exercicio']}{paciente['fumo']} {paciente['checkup_ultimo_ano']} {paciente['idade']} (máximo de 150 caracteres)"
      }
    ]
  )
  return completion.choices[0].message.content.strip('\"')

# Criação da lista para armazenar as mensagens
orientacoes = []

# Iterar sobre cada linha do dataframe e gerar mensagens personalizadas
for index, paciente in pacientes.iterrows():
    mensagem = mensagem_ai(paciente)
    print(mensagem)
    print("\n")
    orientacoes.append(mensagem)
# Out:
# Olá João, lembre-se de administrar sua insulina regularmente e manter uma dieta balanceada. Monitore seus níveis de açúcar no sangue. Saúde em 1º lugar.
#
#
# Olá Maria, lembre-se de sempre se hidratar, ter uma alimentação equilibrada e praticar exercícios moderados. Saúde é prioridade!
#
#
# Oi Carlos, lembre-se de manter a dieta equilibrada, medir o açúcar regularmente e realizar exercícios. Cuide da sua saúde!
#
#
# Olá Ana, busque por atividades físicas que você goste, alimentação balanceada é essencial e beba bastante água. Saúde em primeiro lugar!
#
#
# Olá Paulo, controle sua pressão regularmente. Mantenha uma dieta balanceada, evite sal e pratique exercícios. Saúde em 1º lugar!
#
#
# Olá Julia, importante manter uma rotina de exercícios e alimentação equilibrada. Lembre-se também de hidratar-se bem. Cuide-se!
#
#
# Olá Luiz, lembre-se de manter uma dieta balanceada, realizar atividades físicas regularmente e evitar hábitos prejudiciais. Cuide da sua saúde!
#
#
# ...

# %% [markdown]
# ## **L**oad
#
# Criação e atualização da coluna 'orientaçoes' de cada usuário na Database de pacientes com a nova mensagem gerada.

# %%
pacientes['orientacoes'] = orientacoes
display(pacientes)
# Out:
#    id      nome  idade       sexo  altura  peso  pressao_sistolica  \
# 0   1      João     45  Masculino     175    80                120
# 1   2     Maria     32   Feminino     160    55                110
# 2   3    Carlos     50  Masculino     180    85                130
# 3   4       Ana     28   Feminino     165    50                110
# 4   5     Paulo     62  Masculino     170    75                125
# 5   6     Julia     40   Feminino     155    60                115
# 6   7      Luiz     35  Masculino     178    90                135
# 7   8   Isabela     48   Feminino     163    70                120
# 8   9  Fernando     55  Masculino     175    82                125
# 9  10     Sofia     30   Feminino     168    58                115
#
#    pressao_diastolica doencas_preexistentes pratica_exercicio fumo  \
# 0                  80       Diabetes tipo 1      Semanalmente  Não
# 1                  70               Nenhuma    Ocasionalmente  Não
# ...
